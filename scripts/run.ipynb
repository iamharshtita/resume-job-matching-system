# %%
import pandas as pd

df = pd.read_parquet("../data/processed/resumes_parsed.parquet")

print(df.head())        # first 5 rows
print(df.columns)       # column names
print(df.shape)         # (rows, columns)
# Out:
#                  resume_id                                       cleaned_text  \
# 0  PrimaryResDataSet_00000  hr administrator/marketing associate hr admini...
# 1  PrimaryResDataSet_00001  hr specialist, us hr operations summary versat...
# 2  PrimaryResDataSet_00002  hr director summary over 20 years experience i...
# 3  PrimaryResDataSet_00003  hr specialist summary dedicated, driven, and d...
# 4  PrimaryResDataSet_00004  hr manager skill highlights hr skills hr depar...
#
#   Category            data_source
# 0       HR  PrimaryResDataSet.csv
# 1       HR  PrimaryResDataSet.csv
# 2       HR  PrimaryResDataSet.csv
# 3       HR  PrimaryResDataSet.csv
# 4       HR  PrimaryResDataSet.csv
# Index(['resume_id', 'cleaned_text', 'Category', 'data_source'], dtype='object')
# (12025, 4)
